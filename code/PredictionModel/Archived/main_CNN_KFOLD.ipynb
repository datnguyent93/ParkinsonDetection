# %% [markdown]
# Extract mel-spectrogram from audio

# %%
from sklearn.model_selection import KFold
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.metrics import Precision, Recall

import os
import glob

# %% [markdown]
# Find graphic specs

# %%
 # Get file paths
pd_files = glob.glob("./plots/PD/*.png")
hc_files = glob.glob("./plots/HC/*.png")

# %% [markdown]
# train

# %%
def drop_alpha(x):
    return x[:,:,:3]

# %%
def create_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(640, 480, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam', 
                  loss='binary_crossentropy', 
                  metrics=['accuracy', Precision(name='precision'), Recall(name='recall')])  # Add precision and recall to the metrics
    return model

# %%
# Convert images to numpy arrays
def convert_images_to_array(files):
    images_as_array=[]
    for file in files:
        # Convert image to numpy array
        image = load_img(file, target_size=(640, 480))
        image_arr = img_to_array(image)
        images_as_array.append(image_arr)
    return np.array(images_as_array)

# %%
# Convert images to numpy arrays
pd_images = convert_images_to_array(pd_files)
hc_images = convert_images_to_array(hc_files)

# Create labels
pd_labels = np.ones(len(pd_files))
hc_labels = np.zeros(len(hc_files))

# Concatenate data and labels
data = np.concatenate((pd_images, hc_images), axis=0)
labels = np.concatenate((pd_labels, hc_labels), axis=0)

kfold = KFold(n_splits=5, shuffle=True)

for train, test in kfold.split(data, labels):
    scores = []
    model = create_model()
    model.fit(
        data[train], labels[train], epochs=20)
    scores = model.evaluate(data[test], labels[test], verbose=0)
    print("Accuracy: %.2f%%" % (scores[1] * 100))
    print("Precision: %.2f%%" % (scores[2] * 100))
    print("Recall: %.2f%%" % (scores[3] * 100))
# Out:
# Epoch 1/20
# 2/2 [==============================] - 7s 861ms/step - loss: 2707.1802 - accuracy: 0.5750 - precision: 0.5938 - recall: 0.8261
# Epoch 2/20
# 2/2 [==============================] - 5s 915ms/step - loss: 3910.1177 - accuracy: 0.4750 - precision: 0.6250 - recall: 0.2174
# Epoch 3/20
# 2/2 [==============================] - 5s 801ms/step - loss: 265.2501 - accuracy: 0.5750 - precision: 0.5750 - recall: 1.0000
# Epoch 4/20
# 2/2 [==============================] - 5s 791ms/step - loss: 27.4759 - accuracy: 0.5250 - precision: 0.5625 - recall: 0.7826
# Epoch 5/20
# 2/2 [==============================] - 5s 804ms/step - loss: 42.0670 - accuracy: 0.4250 - precision: 0.5000 - recall: 0.1739
# Epoch 6/20
# 2/2 [==============================] - 5s 812ms/step - loss: 1.7437 - accuracy: 0.6500 - precision: 0.6552 - recall: 0.8261
# Epoch 7/20
# 2/2 [==============================] - 5s 815ms/step - loss: 5.8799 - accuracy: 0.6000 - precision: 0.5897 - recall: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 5s 809ms/step - loss: 1.9891 - accuracy: 0.5500 - precision: 1.0000 - recall: 0.2174
# Epoch 9/20
# 2/2 [==============================] - 5s 842ms/step - loss: 0.2633 - accuracy: 0.9000 - precision: 0.8519 - recall: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 4s 796ms/step - loss: 0.1406 - accuracy: 0.9750 - precision: 0.9583 - recall: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 5s 847ms/step - loss: 0.0656 - accuracy: 0.9750 - precision: 0.9583 - recall: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 4s 808ms/step - loss: 0.0555 - accuracy: 0.9750 - precision: 0.9583 - recall: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 5s 806ms/step - loss: 0.0174 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 5s 799ms/step - loss: 0.0286 - accuracy: 0.9750 - precision: 0.9583 - recall: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 5s 899ms/step - loss: 0.0103 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 5s 794ms/step - loss: 0.0070 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 4s 784ms/step - loss: 4.6108e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 4s 777ms/step - loss: 4.1024e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 4s 766ms/step - loss: 6.7706e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 4s 770ms/step - loss: 1.7272e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Accuracy: 81.82%
# Precision: 71.43%
# Recall: 100.00%
# Epoch 1/20
# 2/2 [==============================] - 7s 951ms/step - loss: 3644.1846 - accuracy: 0.5122 - precision: 0.5625 - recall: 0.7500
# Epoch 2/20
# 2/2 [==============================] - 6s 868ms/step - loss: 3445.3286 - accuracy: 0.4390 - precision: 0.5556 - recall: 0.2083
# Epoch 3/20
# 2/2 [==============================] - 5s 864ms/step - loss: 411.2663 - accuracy: 0.5854 - precision: 0.5854 - recall: 1.0000
# Epoch 4/20
# 2/2 [==============================] - 5s 880ms/step - loss: 248.0953 - accuracy: 0.4634 - precision: 0.7500 - recall: 0.1250
# Epoch 5/20
# 2/2 [==============================] - 5s 875ms/step - loss: 133.3647 - accuracy: 0.5854 - precision: 0.5854 - recall: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 5s 888ms/step - loss: 26.0286 - accuracy: 0.4390 - precision: 0.5556 - recall: 0.2083
# Epoch 7/20
# 2/2 [==============================] - 5s 946ms/step - loss: 26.0900 - accuracy: 0.3415 - precision: 0.3333 - recall: 0.1250
# Epoch 8/20
# 2/2 [==============================] - 5s 855ms/step - loss: 1.9252 - accuracy: 0.7561 - precision: 1.0000 - recall: 0.5833
# Epoch 9/20
# 2/2 [==============================] - 5s 904ms/step - loss: 0.6343 - accuracy: 0.9268 - precision: 0.8889 - recall: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 5s 919ms/step - loss: 0.1578 - accuracy: 0.9756 - precision: 0.9600 - recall: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 6s 992ms/step - loss: 2.8030e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 5s 897ms/step - loss: 0.0099 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 5s 908ms/step - loss: 2.6672e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 6s 924ms/step - loss: 0.0576 - accuracy: 0.9756 - precision: 1.0000 - recall: 0.9583
# Epoch 15/20
# 2/2 [==============================] - 5s 892ms/step - loss: 0.9136 - accuracy: 0.9268 - precision: 0.8889 - recall: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 5s 875ms/step - loss: 3.4241 - accuracy: 0.7805 - precision: 1.0000 - recall: 0.6250
# Epoch 17/20
# 2/2 [==============================] - 5s 866ms/step - loss: 0.1083 - accuracy: 0.9756 - precision: 0.9600 - recall: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 5s 908ms/step - loss: 0.1033 - accuracy: 0.9756 - precision: 0.9600 - recall: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 5s 879ms/step - loss: 0.0069 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 4s 821ms/step - loss: 5.7667e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Accuracy: 70.00%
# Precision: 57.14%
# Recall: 100.00%
# Epoch 1/20
# 2/2 [==============================] - 5s 825ms/step - loss: 1632.7538 - accuracy: 0.5366 - precision: 0.6667 - recall: 0.2727
# Epoch 2/20
# 2/2 [==============================] - 4s 782ms/step - loss: 4728.5532 - accuracy: 0.5366 - precision: 0.5366 - recall: 1.0000
# Epoch 3/20
# 2/2 [==============================] - 4s 738ms/step - loss: 461.0896 - accuracy: 0.4634 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4/20
# 2/2 [==============================] - 4s 763ms/step - loss: 160.6268 - accuracy: 0.5366 - precision: 0.5366 - recall: 1.0000
# Epoch 5/20
# 2/2 [==============================] - 4s 739ms/step - loss: 74.5190 - accuracy: 0.4634 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6/20
# 2/2 [==============================] - 3s 715ms/step - loss: 50.7403 - accuracy: 0.5366 - precision: 0.5366 - recall: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 4s 728ms/step - loss: 23.5918 - accuracy: 0.5122 - precision: 0.5312 - recall: 0.7727
# Epoch 8/20
# 2/2 [==============================] - 4s 716ms/step - loss: 8.6762 - accuracy: 0.5854 - precision: 1.0000 - recall: 0.2273
# Epoch 9/20
# 2/2 [==============================] - 4s 729ms/step - loss: 3.8654 - accuracy: 0.7073 - precision: 0.6471 - recall: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 4s 777ms/step - loss: 0.2209 - accuracy: 0.9512 - precision: 0.9545 - recall: 0.9545
# Epoch 11/20
# 2/2 [==============================] - 4s 717ms/step - loss: 15.8251 - accuracy: 0.6829 - precision: 0.6364 - recall: 0.9545
# Epoch 12/20
# 2/2 [==============================] - 4s 800ms/step - loss: 3.5126 - accuracy: 0.5610 - precision: 1.0000 - recall: 0.1818
# Epoch 13/20
# 2/2 [==============================] - 4s 741ms/step - loss: 0.2193 - accuracy: 0.8780 - precision: 0.8148 - recall: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 4s 721ms/step - loss: 0.3924 - accuracy: 0.9268 - precision: 1.0000 - recall: 0.8636
# Epoch 15/20
# 2/2 [==============================] - 4s 722ms/step - loss: 1.0511 - accuracy: 0.6829 - precision: 0.6286 - recall: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 4s 741ms/step - loss: 1.6016 - accuracy: 0.7805 - precision: 1.0000 - recall: 0.5909
# Epoch 17/20
# 2/2 [==============================] - 4s 735ms/step - loss: 0.0205 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 4s 719ms/step - loss: 0.1593 - accuracy: 0.9512 - precision: 0.9167 - recall: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 3s 758ms/step - loss: 0.6888 - accuracy: 0.9268 - precision: 0.8800 - recall: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 3s 798ms/step - loss: 0.1365 - accuracy: 0.9512 - precision: 0.9167 - recall: 1.0000
# Accuracy: 80.00%
# Precision: 100.00%
# Recall: 66.67%
# Epoch 1/20
# 2/2 [==============================] - 6s 912ms/step - loss: 2596.3306 - accuracy: 0.5122 - precision: 0.5556 - recall: 0.2381
# Epoch 2/20
# 2/2 [==============================] - 5s 878ms/step - loss: 4304.6016 - accuracy: 0.5122 - precision: 0.5122 - recall: 1.0000
# Epoch 3/20
# 2/2 [==============================] - 5s 931ms/step - loss: 1053.8147 - accuracy: 0.4878 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4/20
# 2/2 [==============================] - 5s 876ms/step - loss: 212.8778 - accuracy: 0.4146 - precision: 0.3333 - recall: 0.1429
# Epoch 5/20
# 2/2 [==============================] - 6s 904ms/step - loss: 344.2476 - accuracy: 0.5122 - precision: 0.5122 - recall: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 5s 922ms/step - loss: 126.6541 - accuracy: 0.4878 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7/20
# 2/2 [==============================] - 5s 909ms/step - loss: 11.0509 - accuracy: 0.4878 - precision: 0.5000 - recall: 0.7619
# Epoch 8/20
# 2/2 [==============================] - 5s 1s/step - loss: 33.6700 - accuracy: 0.5122 - precision: 0.5122 - recall: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 5s 931ms/step - loss: 3.7229 - accuracy: 0.7317 - precision: 1.0000 - recall: 0.4762
# Epoch 10/20
# 2/2 [==============================] - 5s 881ms/step - loss: 6.0842 - accuracy: 0.6829 - precision: 1.0000 - recall: 0.3810
# Epoch 11/20
# 2/2 [==============================] - 5s 961ms/step - loss: 2.2859 - accuracy: 0.7561 - precision: 0.6774 - recall: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 5s 899ms/step - loss: 0.3057 - accuracy: 0.9756 - precision: 0.9545 - recall: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 5s 889ms/step - loss: 0.0568 - accuracy: 0.9756 - precision: 0.9545 - recall: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 5s 892ms/step - loss: 0.1007 - accuracy: 0.9756 - precision: 1.0000 - recall: 0.9524
# Epoch 15/20
# 2/2 [==============================] - 5s 887ms/step - loss: 0.0025 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 5s 892ms/step - loss: 1.5451e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 5s 867ms/step - loss: 1.7259e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 4s 806ms/step - loss: 2.1160e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 4s 835ms/step - loss: 3.6177e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 4s 752ms/step - loss: 7.0973e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Accuracy: 90.00%
# Precision: 100.00%
# Recall: 85.71%
# Epoch 1/20
# 2/2 [==============================] - 6s 890ms/step - loss: 3539.8594 - accuracy: 0.4878 - precision: 0.5556 - recall: 0.2273
# Epoch 2/20
# 2/2 [==============================] - 5s 1s/step - loss: 4977.5200 - accuracy: 0.5366 - precision: 0.5366 - recall: 1.0000
# Epoch 3/20
# 2/2 [==============================] - 6s 924ms/step - loss: 2027.7941 - accuracy: 0.4634 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4/20
# 2/2 [==============================] - 5s 927ms/step - loss: 109.7982 - accuracy: 0.5122 - precision: 0.5312 - recall: 0.7727
# Epoch 5/20
# 2/2 [==============================] - 5s 899ms/step - loss: 255.0646 - accuracy: 0.5366 - precision: 0.5366 - recall: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 5s 902ms/step - loss: 7.4768 - accuracy: 0.6585 - precision: 1.0000 - recall: 0.3636
# Epoch 7/20
# 2/2 [==============================] - 5s 942ms/step - loss: 27.2791 - accuracy: 0.7561 - precision: 0.7308 - recall: 0.8636
# Epoch 8/20
# 2/2 [==============================] - 5s 926ms/step - loss: 17.4667 - accuracy: 0.4878 - precision: 1.0000 - recall: 0.0455
# Epoch 9/20
# 2/2 [==============================] - 6s 892ms/step - loss: 6.5682 - accuracy: 0.6098 - precision: 0.5789 - recall: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 5s 940ms/step - loss: 1.3512 - accuracy: 0.8049 - precision: 0.8500 - recall: 0.7727
# Epoch 11/20
# 2/2 [==============================] - 5s 937ms/step - loss: 1.1456 - accuracy: 0.8780 - precision: 1.0000 - recall: 0.7727
# Epoch 12/20
# 2/2 [==============================] - 6s 901ms/step - loss: 0.6248 - accuracy: 0.8780 - precision: 0.8148 - recall: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 5s 909ms/step - loss: 0.4290 - accuracy: 0.8780 - precision: 0.8696 - recall: 0.9091
# Epoch 14/20
# 2/2 [==============================] - 5s 944ms/step - loss: 0.5581 - accuracy: 0.9024 - precision: 1.0000 - recall: 0.8182
# Epoch 15/20
# 2/2 [==============================] - 5s 902ms/step - loss: 0.6001 - accuracy: 0.8780 - precision: 1.0000 - recall: 0.7727
# Epoch 16/20
# 2/2 [==============================] - 4s 877ms/step - loss: 0.2769 - accuracy: 0.9512 - precision: 1.0000 - recall: 0.9091
# Epoch 17/20
# 2/2 [==============================] - 5s 848ms/step - loss: 0.0413 - accuracy: 0.9756 - precision: 0.9565 - recall: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 4s 840ms/step - loss: 0.0449 - accuracy: 0.9756 - precision: 0.9565 - recall: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 5s 939ms/step - loss: 0.0523 - accuracy: 0.9756 - precision: 0.9565 - recall: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 4s 744ms/step - loss: 0.0400 - accuracy: 0.9756 - precision: 0.9565 - recall: 1.0000
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x2ac545ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Accuracy: 70.00%
# Precision: 71.43%
# Recall: 83.33%

# %%
print(scores)
# Out:
# [1.3771628141403198, 0.699999988079071, 0.7142857313156128, 0.8333333134651184]
