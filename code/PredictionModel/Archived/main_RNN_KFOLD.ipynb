# %% [markdown]
# Extract mel-spectrogram from audio

# %%
import glob
import numpy as np
from tensorflow import keras
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from keras.metrics import Precision, Recall
from sklearn.metrics import accuracy_score, precision_score, recall_score, log_loss
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.preprocessing.image import img_to_array, load_img
from keras.applications.vgg16 import preprocess_input
import os
from sklearn.model_selection import KFold
from sklearn.model_selection import KFold

# %% [markdown]
# Find graphic specs

# %%
def load_data(dir_path):
   X = []
   y = []
   labels = ['PD', 'HC']
   for label in labels:
      path = os.path.join(dir_path, label)
      class_num = labels.index(label)
      for img in os.listdir(path):
         try:
               img_arr = img_to_array(load_img(os.path.join(path, img), target_size=(640, 480)))  # Convert image to array
               X.append(preprocess_input(img_arr))  # Preprocess the image using VGG16's preprocess_input method
               y.append(class_num)
         except Exception as e:
               print(e)
      try:
            return np.array(X), np.array(y)
      except Exception as e:
            print(f'Failed to create numpy arrays: {e}')
            return None, None

# %%
X, y = load_data('./plots/')
X = X.reshape(X.shape[0], -1, 1)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# Reshape for RNN
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))

num_folds = 5

# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []
precision_per_fold = []
recall_per_fold = []

# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True)

# %% [markdown]
# train

# %%
# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(X, y):

  # Define the model architecture
  model = Sequential()
  model.add(SimpleRNN(50, activation='relu', input_shape=(X_train.shape[1], 1)))
  model.add(Dense(1, activation='sigmoid'))

  # Compile the model
  model.compile(loss='binary_crossentropy', 
                optimizer='adam', 
                metrics=['accuracy', Precision(), Recall()])

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  # Fit data to model
  history = model.fit(X[train], y[train], epochs=50, verbose=1)

  # Generate generalization metrics
  scores = model.evaluate(X[test], y[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%; {model.metrics_names[2]} of {scores[2]*100}%; {model.metrics_names[3]} of {scores[3]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])
  precision_per_fold.append(scores[2])
  recall_per_fold.append(scores[3])

  # Increase fold number
  fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/50
# 1/1 [==============================] - 42s 42s/step - loss: 239.7336 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 41s 41s/step - loss: 235.2355 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3/50
# 1/1 [==============================] - 41s 41s/step - loss: 230.8431 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 41s 41s/step - loss: 226.5546 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 41s 41s/step - loss: 222.3683 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6/50
# 1/1 [==============================] - 41s 41s/step - loss: 218.2822 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7/50
# 1/1 [==============================] - 42s 42s/step - loss: 214.2943 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8/50
# 1/1 [==============================] - 41s 41s/step - loss: 209.6898 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9/50
# 1/1 [==============================] - 41s 41s/step - loss: 204.5329 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10/50
# 1/1 [==============================] - 41s 41s/step - loss: 199.4650 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11/50
# 1/1 [==============================] - 41s 41s/step - loss: 194.4901 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12/50
# 1/1 [==============================] - 41s 41s/step - loss: 189.6139 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13/50
# 1/1 [==============================] - 42s 42s/step - loss: 184.8404 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14/50
# 1/1 [==============================] - 41s 41s/step - loss: 180.1724 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15/50
# 1/1 [==============================] - 41s 41s/step - loss: 175.3740 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16/50
# 1/1 [==============================] - 45s 45s/step - loss: 169.9564 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17/50
# 1/1 [==============================] - 39s 39s/step - loss: 164.6391 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18/50
# 1/1 [==============================] - 65s 65s/step - loss: 159.4270 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19/50
# 1/1 [==============================] - 41s 41s/step - loss: 154.3231 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20/50
# 1/1 [==============================] - 41s 41s/step - loss: 149.3290 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 21/50
# 1/1 [==============================] - 41s 41s/step - loss: 144.4451 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 22/50
# 1/1 [==============================] - 41s 41s/step - loss: 139.6708 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 23/50
# 1/1 [==============================] - 50s 50s/step - loss: 135.0050 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 24/50
# 1/1 [==============================] - 42s 42s/step - loss: 130.4459 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 25/50
# 1/1 [==============================] - 41s 41s/step - loss: 125.9914 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 26/50
# 1/1 [==============================] - 41s 41s/step - loss: 121.6390 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 27/50
# 1/1 [==============================] - 41s 41s/step - loss: 117.3861 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 28/50
# 1/1 [==============================] - 41s 41s/step - loss: 113.2297 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 29/50
# 1/1 [==============================] -
- accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 29/50
# 1/1 [==============================] - 41s 41s/step - loss: 38.4740 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 30/50
# 1/1 [==============================] - 41s 41s/step - loss: 38.1604 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 31/50
# 1/1 [==============================] - 40s 40s/step - loss: 37.8494 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 32/50
# 1/1 [==============================] - 41s 41s/step - loss: 37.5412 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 33/50
# 1/1 [==============================] - 41s 41s/step - loss: 37.2355 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 34/50
# 1/1 [==============================] - 41s 41s/step - loss: 36.9375 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 35/50
# 1/1 [==============================] - 41s 41s/step - loss: 36.7318 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 36/50
# 1/1 [==============================] - 41s 41s/step - loss: 36.5262 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 37/50
# 1/1 [==============================] - 41s 41s/step - loss: 36.3210 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 38/50
# 1/1 [==============================] - 41s 41s/step - loss: 36.1161 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 39/50
# 1/1 [==============================] - 41s 41s/step - loss: 35.9116 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 40/50
# 1/1 [==============================] - 41s 41s/step - loss: 35.7075 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 41/50
# 1/1 [==============================] - 41s 41s/step - loss: 35.5040 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 42/50
# 1/1 [==============================] - 41s 41s/step - loss: 35.3010 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 43/50
# 1/1 [==============================] - 41s 41s/step - loss: 35.0987 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 44/50
# 1/1 [==============================] - 41s 41s/step - loss: 34.8969 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 45/50
# 1/1 [==============================] - 41s 41s/step - loss: 34.6957 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 46/50
# 1/1 [==============================] - 40s 40s/step - loss: 34.4953 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 47/50
# 1/1 [==============================] - 41s 41s/step - loss: 34.2955 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 48/50
# 1/1 [==============================] - 41s 41s/step - loss: 34.0965 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 49/50
# 1/1 [==============================] - 40s 40s/step - loss: 33.8981 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Epoch 50/50
# 1/1 [==============================] - 40s 40s/step - loss: 33.7006 - accuracy: 0.0000e+00 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00
# Score for fold 4: loss of 33.50380325317383; accuracy of 0.0%; precision_3 of 0.0%; recall_3 of 0.0%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/50
# 1/1 [==============================] - 41s 41s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 3/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 6/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 7/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 8/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 9/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 10/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 11/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 12/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 13/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 14/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 15/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 16/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 17/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 18/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 19/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 20/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 21/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 22/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 23/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 24/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 25/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 26/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 27/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 28/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 29/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 30/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 31/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 32/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 33/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 34/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 35/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 36/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 37/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 38/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 39/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 40/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 41/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 42/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 43/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 44/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 45/50
# 1/1 [==============================] - 40s 40s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 46/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 47/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 48/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 49/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# Epoch 50/50
# 1/1 [==============================] - 39s 39s/step - loss: 6.3851e-33 - accuracy: 1.0000 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x000002DA8D3F9940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Score for fold 5: loss of 6.385105316094196e-33; accuracy of 100.0%; precision_4 of 0.0%; recall_4 of 0.0%

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}% - Precision: {precision_per_fold[i]} - Recall: {recall_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print(f'> Precision: {np.mean(precision_per_fold)}')
print(f'> Recall: {np.mean(recall_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 21.007156372070312 - Accuracy: 0.0% - Precision: 0.0 - Recall: 0.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.0 - Accuracy: 100.0% - Precision: 0.0 - Recall: 0.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.0 - Accuracy: 100.0% - Precision: 0.0 - Recall: 0.0%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 33.50380325317383 - Accuracy: 0.0% - Precision: 0.0 - Recall: 0.0%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 6.385105316094196e-33 - Accuracy: 100.0% - Precision: 0.0 - Recall: 0.0%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 60.0 (+- 48.98979485566356)
# > Loss: 10.902191925048829
# > Precision: 0.0
# > Recall: 0.0
# ------------------------------------------------------------------------

# %%
# Plotting Accuracy, Loss, Precision and Recall
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(acc_per_fold)
plt.title('Model Accuracy per fold')
plt.ylabel('Accuracy')
plt.xlabel('Fold')

plt.subplot(2,2,2)
plt.plot(loss_per_fold)
plt.title('Model Loss per fold')
plt.ylabel('Loss')
plt.xlabel('Fold')

plt.subplot(2,2,3)
#plt.plot(precision_per_fold)
plt.bar(precision_per_fold, height=10)
plt.title('Model Precision per fold')
plt.ylabel('Precision')
plt.xlabel('Fold')


plt.subplot(2,2,4)
plt.plot(recall_per_fold)
plt.title('Model Recall per fold')
plt.ylabel('Recall')
plt.xlabel('Fold')
plt.show()
